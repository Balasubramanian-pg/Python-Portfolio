# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset from an Excel file
csv_file_path = r"A:\Semester 4\1.Dissertation\Analysis and Interpretation\B2B Questionnaire (Responses) - Form Responses 1.csv"  # Update with your file path
data = pd.read_csv(csv_file_path)

# %%
print(data.head)
# Out:
# <bound method NDFrame.head of               Timestamp                Company Name           Industry  \
# 0      11-07-2023 09:20              Value Xchange          Healthcare
# 1      11-07-2023 09:26                Value scale          Technology
# 2      11-07-2023 10:33                   Deflytics         Technology
# 3      11-07-2023 10:41                   Digitelic         Technology
# 4      11-07-2023 22:00                    Rephusti         Technology
# ..                  ...                         ...                ...
# 86  11/13/2023 13:35:00                Simplex MLM          Technology
# 87  11/13/2023 13:38:02                    Emphora   Digital Marketing
# 88  11/13/2023 13:39:06                 BetterZilla         Technology
# 89  11/13/2023 13:45:17  SKC Management Consultancy         Consulting
# 90  11/13/2023 13:47:52                 Classic Hub  Digital Marketing
#
#          Client_tenure Emp_size CRM_Awareness CRM_Strat_rating\n  \
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of               Timestamp                Company Name           Industry  \
# 0      11-07-2023 09:20              Value Xchange          Healthcare
# 1      11-07-2023 09:26                Value scale          Technology
# 2      11-07-2023 10:33                   Deflytics         Technology
# 3      11-07-2023 10:41                   Digitelic         Technology
# 4      11-07-2023 22:00                    Rephusti         Technology
# ..                  ...                         ...                ...
# 86  11/13/2023 13:35:00                Simplex MLM          Technology
# 87  11/13/2023 13:38:02                    Emphora   Digital Marketing
# 88  11/13/2023 13:39:06                 BetterZilla         Technology
# 89  11/13/2023 13:45:17  SKC Management Consultancy         Consulting
# 90  11/13/2023 13:47:52                 Classic Hub  Digital Marketing
#
#          Client_tenure Emp_size CRM_Awareness CRM_Strat_rating\n  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is the DataFrame containing your dataset
# Replace 'data' with the actual variable name if it's different

# List of categorical columns
categorical_columns = ['Company Name', 'Industry', 'Client_tenure', 'Emp_size', 'CRM_Awareness',
                        'CRM_Strat_rating', 'Satisfaction', 'Purchases', 'Intend_to_continue_purchase',
                        'Recommendation', 'Advocacy', 'Customer_loyalty_indication', 'Strategy_influence',
                        'Specific_CRM_Strategies', 'Effective_dimensions']

# Set up subplots
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 15))
fig.subplots_adjust(hspace=0.5)

# Flatten the axes for easier iteration
axes = axes.flatten()

# Generate count plots for each categorical variable
for i, column in enumerate(categorical_columns):
    sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
    axes[i].set_title(f'Countplot of {column}')
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# a:\Semester 4\1.Dissertation\Analysis and Interpretation\Ananthu.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/a%3A/Semester%204/1.Dissertation/Analysis%20and%20Interpretation/Ananthu.ipynb#W4sZmlsZQ%3D%3D?line=19'>20</a> # Generate count plots for each categorical variable
#      <a href='vscode-notebook-cell:/a%3A/Semester%204/1.Dissertation/Analysis%20and%20Interpretation/Ananthu.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a> for i, column in enumerate(categorical_columns):
# ---> <a href='vscode-notebook-cell:/a%3A/Semester%204/1.Dissertation/Analysis%20and%20Interpretation/Ananthu.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a>     sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# ...

# %%
import pandas as pd

# Load the dataset from an Excel file
excel_file_path = r"A:\Semester 4\1.Dissertation\Analysis and Interpretation\B2B Questionnaire (Responses) - Form Responses 1.csv"  # Update with your file path
data = pd.read_csv(excel_file_path)

# Display count of all categories for each column
for column in data.columns:
    print(f"\nValue Counts for {column}:")
    print(data[column].value_counts())
# Out:
# Value Counts for Timestamp:
# 11-09-2023 23:36       2
# 11-07-2023 09:20       1
# 11/13/2023 12:36:13    1
# 11/13/2023 12:31:52    1
# 11/13/2023 12:29:55    1
#                       ..
# 11-10-2023 01:15       1
# 11-10-2023 00:35       1
# 11-10-2023 00:15       1
# 11-09-2023 23:45       1
# 11/13/2023 13:47:52    1
# Name: Timestamp, Length: 90, dtype: int64
#
# Value Counts for Company Name:
# Value Xchange     1
# LuvThat Design    1
# Qapitol QA        1
# Asmadiya          1
# Profit Wheel      1
#                  ..
# KiwiQA            1
# Nimblechapps      1
# Cacti legal       1
# 360 Realtors      1
# Classic Hub       1
# Name: Company Name, Length: 91, dtype: int64
#
# Value Counts for Industry:
# Technology              32
# Finance                 11
# Education               10
# Healthcare               9
# Manufacturing            8
# SaaS                     6
# Consulting               3
# Advertising              2
# Digital Marketing        2
# ...

# %%
import pandas as pd
import pingouin as pg
from sklearn.preprocessing import LabelEncoder

# Load the dataset from a CSV file
csv_file_path = r"A:\Semester 4\1.Dissertation\Analysis and Interpretation\B2B Questionnaire (Responses) - Form Responses 1.csv"  # Update with your file path
data = pd.read_csv(csv_file_path)

# Print the column names to identify any issues with leading/trailing spaces or special characters
print("Column Names in the DataFrame:")
print(data.columns)

# Extract columns that you want to include in Cronbach's alpha calculation
selected_columns = data[['Company Name', 'Industry', 'Client_tenure', 'Emp_size', 'CRM_Awareness',
                          'Purchases', 'Intend_to_continue_purchase',
                         'Recommendation', 'Advocacy', 'Customer_loyalty_indication', 'Strategy_influence',
                         'Specific_CRM_Strategies', 'Effective_dimensions']]

# Print the selected columns to double-check their names
print("Selected Columns:")
print(selected_columns.columns)

# Convert string data to numeric values using LabelEncoder
label_encoder = LabelEncoder()
selected_columns_numeric = selected_columns.apply(lambda col: label_encoder.fit_transform(col.astype(str)))

# Calculate Cronbach's alpha
alpha_result = pg.cronbach_alpha(data=selected_columns_numeric)

# Display the Cronbach's alpha value
print("Cronbach's Alpha:")
print(alpha_result[0])  # Access the first element of the tuple, which is the alpha value
# Out:
# Column Names in the DataFrame:
# Index(['Timestamp', 'Company Name', 'Industry', 'Client_tenure', 'Emp_size',
#        'CRM_Awareness', 'CRM_Strat_rating\n', 'Satisfaction\n', 'Purchases',
#        'Intend_to_continue_purchase', 'Recommendation', 'Advocacy',
#        'Customer_loyalty_indication', 'Strategy_influence',
#        'Specific_CRM_Strategies', 'Effective_dimensions'],
#       dtype='object')
# Selected Columns:
# Index(['Company Name', 'Industry', 'Client_tenure', 'Emp_size',
#        'CRM_Awareness', 'Purchases', 'Intend_to_continue_purchase',
#        'Recommendation', 'Advocacy', 'Customer_loyalty_indication',
#        'Strategy_influence', 'Specific_CRM_Strategies',
#        'Effective_dimensions'],
#       dtype='object')
# Cronbach's Alpha:
# -0.04590708648953529

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Load the dataset from an Excel file
excel_file_path = r"A:\Semester 4\1.Dissertation\Analysis and Interpretation\B2B Questionnaire (Responses) - Form Responses 1.csv"  # Update with your file path
data = pd.read_csv(excel_file_path)

# Assuming you have two categorical columns A and B, replace them with your actual column names
column_A = 'CRM_Awareness'
column_B = 'Customer_loyalty_indication'

# Create a contingency table
contingency_table = pd.crosstab(data[column_A], data[column_B])

# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Display the results
print(f"Chi-square value: {chi2}")
print(f"P-value: {p}")

# Check for significance
alpha = 0.05
if p < alpha:
    print("There is a significant relationship between the two variables.")
else:
    print("There is no significant relationship between the two variables.")
# Out:
# Chi-square value: 72.26612050739958
# P-value: 0.0045985186387110955
# There is a significant relationship between the two variables.
